# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns  # for nicer graphics

from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
data =boston['data']
target=boston['target']

data.shape
# Out:
# (506, 13)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
tabledata = np.c_[data,target]
data_names =   boston['feature_names']
target_names = np.array(['MEDV'])

tableColumns = np.append(data_names,target_names)

Table = pd.DataFrame(data =tabledata,columns =tableColumns)

# %%
Table.shape
# Out:
# (506, 14)

# %% [markdown]
# **Making Histogram to find most common occurance target medv**

# %%
plt.figure(figsize=(7,6), dpi=100)
plt.hist(Table['MEDV'])
plt.xlabel("Prices in 1000's",size=12)
plt.ylabel("No Of property",size=12)
plt.figure(figsize=(18,12))
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(Table['DIS'],Table['MEDV'],"ys")
plt.xlabel("Employment Centre",size=12)
plt.ylabel("Price",size=12)

# if i want to plot all features in single graph then i have to standardise it to check
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.figure(figsize=(7,6), dpi=100)
plt.hist(Table['MEDV'])
plt.xlabel("Prices in 1000's",size=12)
plt.ylabel("No Of property",size=12)
plt.figure(figsize=(18,12))
plt.show()

# %%
Table
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
X = Table.iloc[:,0:13]
y = Table.iloc[:,-1]

# %%
X
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
# feature selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression


# i cannot use chisquare since its only for classification

# %%
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=f_regression, k=10)
fit = bestfeatures.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  #naming the dataframe columns

# %%
featureScores.nlargest(13,'Score')
# Out:
#    Features       Score
# 12    LSTAT  601.617871
# 5        RM  471.846740
# 10  PTRATIO  175.105543
# 2     INDUS  153.954883
# 9       TAX  141.761357
# 4       NOX  112.591480
# 0      CRIM   89.486115
# 8       RAD   85.914278
# 6       AGE   83.477459
# 1        ZN   75.257642
# 11        B   63.054229
# 7       DIS   33.579570
# 3      CHAS   15.971512

# %%
# from the above results removing features which are not useful and also to reduce variance

#Table.drop(['CHAS','DIS','B','ZN'],axis = 1,inplace =True)

# %%
# feature selection did not workout so i did not use feature selection in predicting


X = Table.iloc[:,0:13]
y = Table.iloc[:,-1]

# %%
X
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
  X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=29)

# %%
X_val.shape
# Out:
# (102, 13)

# %%
from sklearn.linear_model import LinearRegression

# %%
linearmodel = LinearRegression()
poly_features = PolynomialFeatures(degree=2, include_bias=False)
scaler = StandardScaler()

#  ("poly_features", poly_features),
# ("scaler", scaler),
regression = Pipeline(
        [
            ("poly_features", poly_features),
            ("scaler", scaler),
            ("model", linearmodel),
        ]
    )

# %%
regression.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('poly_features', PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('model', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False))])

# %%
regression.score(X_val,y_val)
# Out:
# 0.8003390023531937

# %%
regression.predict(X_val[21:22])
# Out:
# array([21.7550041])

# %%
y_val[21:22]
# Out:
# 319    21.0
# Name: MEDV, dtype: float64
